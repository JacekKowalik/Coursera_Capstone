# %% [markdown]
# <h1>Introduction/Business Problem</h1>
# <p>Company A is a Real Estate Agency that is working for corporations.
# One of the biggest client (Company B) has offices in the following cities:
# <ul>
#     <li>Paris</li>
#     <li>London</li>
#     <li>Berlin</li>
#     <li>New York</li>
#     <li>Tokyo</li>
# </ul>
# Company B's employees are rotating between offices and there is a need to do house-hunting, which is a task for company A. Usually people want to live in similar district as before. For example, if today I am working in Tokyo and my next assignment is in Berlin I would like to find the place which will be similar to the one I have in Tokyo.
# In this notebook, we will build the model which clusters all districts from the above cities and help Company A in finding the best places to live for their client.</p>

# %%
#!conda install -c conda-forge geopy --yes 
import numpy as np
import pandas as pd
import json
from geopy.geocoders import Nominatim
import requests

# %% [markdown]
# <h1>Data</h1>
# <p>Data for this project will come from following sources: </p>
# <ul>
#     <li> Paris Data: https://www.data.gouv.fr/ </li>
#     <li> Tokyo Data: https://en.wikipedia.org/wiki/Special_wards_of_Tokyo </li>
#     <li> London Data: https://en.wikipedia.org/wiki/List_of_London_boroughs </li>
#     <li> Berlin Data: https://en.wikipedia.org/wiki/Boroughs_and_neighborhoods_of_Berlin </li>
#     <li> New York Data: https://en.wikipedia.org/wiki/Boroughs_of_New_York_City </li>
#
# </ul>
#
# <p>In this part of the notebook we will first get borough data for each city together with latitude and longitude, next we will gather all data together and create final_df which will contain following information:
#     <ul>
#         <li>City Name</li>
#         <li>District Name</li>
#         <li>Latitude</li>
#         <li>Longitude</li>
#     </ul>
#     Then we will use final_df dataframe to get data regarding nearby venues for each district from Foursquare API</p>
#     <p> For Paris I downloaded ready json file, for the rest I scraped data from Wikipedia page and found Lat and Lon using geopy </p>

# %% [markdown]
# <h2>Paris Data</h2>

# %%
# !wget -q -O 'paris_data.json' https://www.data.gouv.fr/en/datasets/r/871c68bf-c92b-42a9-8dcc-910f9be0b870

# %%
with open('paris_data.json') as json_data:
    paris_data = json.load(json_data)

# %%
paris_data[0]
# Out:
# {'datasetid': 'arrondissements',
#  'recordid': 'ed26ad57eff28ccd16d66834c44723d942771958',
#  'fields': {'n_sq_co': 750001537,
#   'perimetre': 13678.7983149,
#   'l_ar': '15ème Ardt',
#   'surface': 8494994.08101075,
#   'geom_x_y': [48.8400853759, 2.29282582242],
#   'geom': {'type': 'Polygon',
#    'coordinates': [[[2.299322310264648, 48.852174427333274],
#      [2.300883913456113, 48.851176131084145],
#      [2.300964661201576, 48.85123012651538],
#      [2.303746047913422, 48.84943929154836],
#      [2.306149310004038, 48.84789994583024],
#      [2.307339709005096, 48.847139376795404],
#      [2.3080419591723302, 48.84739225374763],
#      [2.308219888290114, 48.847434925901986],
#      [2.310378251508753, 48.84795218786006],
#      [2.310525952151246, 48.84798758363206],
#      [2.311155377296785, 48.84757938949668],
#      [2.311260835819493, 48.847510996658556],
#      [2.311486631207579, 48.847368855176626],
#      [2.311625847644086, 48.847281216555366],
#      [2.311767709159531, 48.84719033639172],
#      [2.312091028580114, 48.846983212758936],
#      [2.313641280957853, 48.845990046203234],
#      [2.313729873598172, 48.84593328656336],
#      [2.288853604944625, 48.85733712105006],
#      [2.288866265474489, 48.85735529584472],
#      [2.288910545466269, 48.85741700303566],
#      [2.288940302714653, 48.85745847112639],
#      [2.289007548819246, 48.857540155446905],
#      [2.289056833076756, 48.85759403552591],
#      [2.289129267169513, 48.85766411921116],
#      [2.289839040379379, 48.858240852910015],
#      [2.290327420911721, 48.85792921935711],
#      [2.290337220001545, 48.85792296668829],
#      [2.290340730189204, 48.857920726523844],
#      [2.290347016363241, 48.85791671400249],
#      [2.290356811347552, 48.85791046220704],
#      [2.290366607692297, 48.85790421041883],
#      [2.290376402684053, 48.85789795772246],
#      [2.290386199024097, 48.857891705932566],
#      [2.290395995361893, 48.85788545414185],
#      [2.290405790358843, 48.85787920054366],
#      [2.290411987116157, 48.85787524774541],
#      [2.290415586679587, 48.85787294965055],
#      [2.29042538165969, 48.85786669694998],
#      [2.290435177987979, 48.8578604451559],
#      [2.2904449743139192, 48.85785419336102],
#      [2.290454769274722, 48.85784794155719],
#      [2.290464565608205, 48.857841688861356],
#      [2.290474361951584, 48.857835435265365],
#      [2.290484158268119, 48.85782918346714],
#      [2.290493953219519, 48.85782293165997],
#      [2.290503749531353, 48.85781667986005],
#      [2.290513543127311, 48.857810427143825],
#      [2.290523340797328, 48.8578041753503],
#      [2.290533137114455, 48.8577979226486],
#      [2.290542932054, 48.857791670837265],
#      [2.290549110963099, 48.857787726020156],
#      [2.290552728354078, 48.857785419033156],
#      [2.290562527353085, 48.85777916904292],
#      [2.290572326349741, 48.85777291905187],
#      [2.290582125356189, 48.857766668160714],
#      [2.290591924335898, 48.857760419067276],
#      [2.290601723337746, 48.85775416817441],
#      [2.290611522324999, 48.85774791817999],
#      [2.290621248453761, 48.85774171362002],
#      [2.29070227350634, 48.85769001146594],
#      [2.290780998017134, 48.85763978855226],
#      [2.292935322260579, 48.85626502245174],
#      [2.293079176013769, 48.85617407768941],
#      [2.29574570829236, 48.85446598873217],
#      [2.295868050746559, 48.854387490546586],
#      [2.295929526344629, 48.85434804668676],
#      [2.297388894455644, 48.85341164261926],
#      [2.297923418787436, 48.853068650104696],
#      [2.299322310264648, 48.852174427333274]]]},
#   'n_sq_ar': 750000015,
#   'l_aroff': 'Vaugirard',
#   'c_arinsee': 75115,
#   'c_ar': 15},
#  'geometry': {'type': 'Point', 'coordinates': [2.29282582242, 48.8400853759]},
#  'record_timestamp': '2020-08-03T10:00:23.921+02:00'}

# %%
column_names = ['City', 'District', 'Latitude', 'Longitude']
paris_district=pd.DataFrame(columns=column_names)
for data in paris_data:
    district_name=data['fields']['l_aroff']
    latlon=data['geometry']['coordinates']
    lon=latlon[0]
    lat=latlon[1]
    paris_district=paris_district.append({'City': 'Paris', 'District' : district_name, 'Latitude': lat, 'Longitude': lon}, ignore_index=True)
paris_district
# Out:
#      City             District   Latitude  Longitude
# 0   Paris            Vaugirard  48.840085   2.292826
# 1   Paris                Opéra  48.877164   2.337458
# 2   Paris    Buttes-Montmartre  48.892569   2.348161
# 3   Paris           Luxembourg  48.849130   2.332898
# 4   Paris              Reuilly  48.834974   2.421325
# 5   Paris  Batignolles-Monceau  48.887327   2.306777
# 6   Paris         Ménilmontant  48.863461   2.401188
# 7   Paris               Louvre  48.862563   2.336443
# 8   Paris               Bourse  48.868279   2.342803
# 9   Paris      Buttes-Chaumont  48.887076   2.384821
# 10  Paris             Panthéon  48.844443   2.350715
# 11  Paris               Élysée  48.872721   2.312554
# 12  Paris                Passy  48.860392   2.261971
# 13  Paris             Entrepôt  48.876130   2.360728
# 14  Paris       Hôtel-de-Ville  48.854341   2.357630
# 15  Paris         Observatoire  48.829245   2.326542
# 16  Paris           Popincourt  48.859059   2.380058
# 17  Paris             Gobelins  48.828388   2.362272
# 18  Paris               Temple  48.862872   2.360001
# 19  Paris       Palais-Bourbon  48.856174   2.312188

# %% [markdown]
# <h2>Tokyo Data</h2>

# %%
tokyo_data=pd.read_html('https://en.wikipedia.org/wiki/Special_wards_of_Tokyo')
tokyo_data[3]['Name']
# Out:
# 0        Chiyoda
# 1           Chūō
# 2         Minato
# 3       Shinjuku
# 4         Bunkyō
# 5          Taitō
# 6         Sumida
# 7           Kōtō
# 8      Shinagawa
# 9         Meguro
# 10           Ōta
# 11      Setagaya
# 12       Shibuya
# 13        Nakano
# 14      Suginami
# 15       Toshima
# 16          Kita
# 17       Arakawa
# 18      Itabashi
# 19        Nerima
# 20        Adachi
# 21    Katsushika
# 22       Edogawa
# 23       Overall
# Name: Name, dtype: object

# %%
geolocator = Nominatim(user_agent="lat_lon_data")
#function to get lan and lon
def get_lon_lat(name_list, city_name, column_names):
    final_df=pd.DataFrame(columns=column_names)
    for singleName in name_list:
        location=geolocator.geocode(singleName)
        lat = location.latitude
        lon = location.longitude
        final_df=final_df.append({'City': city_name, 'District' : singleName, 'Latitude': lat, 'Longitude': lon}, ignore_index=True)
    return final_df
column_names = ['City', 'District', 'Latitude', 'Longitude']

# %%
tokyo_district=get_lon_lat(tokyo_data[3]['Name'], 'Tokyo', column_names)
tokyo_district
# Out:
#      City    District   Latitude   Longitude
# 0   Tokyo     Chiyoda  35.693810  139.753216
# 1   Tokyo        Chūō  35.666255  139.775565
# 2   Tokyo      Minato  35.643227  139.740055
# 3   Tokyo    Shinjuku  35.693763  139.703632
# 4   Tokyo      Bunkyō  35.718810  139.744732
# 5   Tokyo       Taitō  35.717450  139.790859
# 6   Tokyo      Sumida  35.700429  139.805017
# 7   Tokyo        Kōtō  35.649154  139.812790
# 8   Tokyo   Shinagawa  35.599252  139.738910
# 9   Tokyo      Meguro  35.621250  139.688014
# 10  Tokyo         Ōta  35.561206  139.715843
# 11  Tokyo    Setagaya  35.646096  139.656270
# 12  Tokyo     Shibuya  35.664596  139.698711
# 13  Tokyo      Nakano  35.718123  139.664468
# 14  Tokyo    Suginami  35.699493  139.636288
# 15  Tokyo     Toshima  35.736156  139.714222
# 16  Tokyo        Kita  -0.220164  -78.512327
# 17  Tokyo     Arakawa  35.737529  139.781310
# 18  Tokyo    Itabashi  35.774143  139.681209
# 19  Tokyo      Nerima  35.748360  139.638735
# 20  Tokyo      Adachi  35.783703  139.795319
# 21  Tokyo  Katsushika  35.751733  139.863816
# 22  Tokyo     Edogawa  35.678278  139.871091
# 23  Tokyo     Overall  38.805625  -78.344724

# %% [markdown]
# <h2>London Data</h2>

# %%
def cleanData(x):
    if str(x).find("[")>-1:
        return x[:str(x).find("[")-1]
    else:
        return x

london_data=pd.read_html('https://en.wikipedia.org/wiki/List_of_London_boroughs')
london_data[0]['Borough']=london_data[0][['Borough']].applymap(cleanData)
london_data[0]['Borough']
# Out:
# 0       Barking and Dagenham
# 1                     Barnet
# 2                     Bexley
# 3                      Brent
# 4                    Bromley
# 5                     Camden
# 6                    Croydon
# 7                     Ealing
# 8                    Enfield
# 9                  Greenwich
# 10                   Hackney
# 11    Hammersmith and Fulham
# 12                  Haringey
# 13                    Harrow
# 14                  Havering
# 15                Hillingdon
# 16                  Hounslow
# 17                 Islington
# 18    Kensington and Chelsea
# 19      Kingston upon Thames
# 20                   Lambeth
# 21                  Lewisham
# 22                    Merton
# 23                    Newham
# 24                 Redbridge
# 25      Richmond upon Thames
# 26                 Southwark
# 27                    Sutton
# 28             Tower Hamlets
# 29            Waltham Forest
# 30                Wandsworth
# 31               Westminster
# Name: Borough, dtype: object

# %%
london_district=get_lon_lat(london_data[0]['Borough'], 'London', column_names)
london_district
# Out:
#       City                District   Latitude   Longitude
# 0   London    Barking and Dagenham  51.554117    0.150504
# 1   London                  Barnet  51.653090   -0.200226
# 2   London                  Bexley  39.969238  -82.936864
# 3   London                   Brent  32.937346  -87.164718
# 4   London                 Bromley  51.402805    0.014814
# 5   London                  Camden  39.944840  -75.119891
# 6   London                 Croydon  51.371305   -0.101957
# 7   London                  Ealing  51.512655   -0.305195
# 8   London                 Enfield  51.652085   -0.081018
# 9   London               Greenwich  51.482084   -0.004542
# 10  London                 Hackney  51.543240   -0.049362
# 11  London  Hammersmith and Fulham  51.492038   -0.223640
# 12  London                Haringey  51.587930   -0.105410
# 13  London                  Harrow  51.596827   -0.337316
# 14  London                Havering  51.004361   -2.337475
# 15  London              Hillingdon  51.542519   -0.448335
# 16  London                Hounslow  51.468613   -0.361347
# 17  London               Islington  51.538429   -0.099905
# 18  London  Kensington and Chelsea  51.487542   -0.168220
# 19  London    Kingston upon Thames  51.409627   -0.306262
# 20  London                 Lambeth  51.501301   -0.117287
# 21  London                Lewisham  51.462432   -0.010133
# 22  London                  Merton  51.410803   -0.188099
# 23  London                  Newham  51.530000    0.029318
# 24  London               Redbridge  51.576320    0.045410
# 25  London    Richmond upon Thames  51.440372   -0.305720
# 26  London               Southwark  51.502922   -0.103458
# 27  London                  Sutton  30.567295 -100.643236
# 28  London           Tower Hamlets  51.128863    1.298669
# 29  London          Waltham Forest  42.375640  -71.235800
# 30  London              Wandsworth  51.457027   -0.193261
# 31  London             Westminster  51.500444   -0.126540

# %% [markdown]
# <h2>Berlin Data</h2>

# %%
berlin_data=pd.read_html('https://en.wikipedia.org/wiki/Boroughs_and_neighborhoods_of_Berlin')
berlin_data[0]
# Out:
#                        Borough  Population 31 March 2010  Area in km²  \
# 0   Charlottenburg-Wilmersdorf                    319628        64.72
# 1     Friedrichshain-Kreuzberg                    268225        20.16
# 2                  Lichtenberg                    259881        52.29
# 3          Marzahn-Hellersdorf                    248264        61.74
# 4                        Mitte                    332919        39.47
# 5                     Neukölln                    310283        44.93
# 6                       Pankow                    366441       103.01
# 7                Reinickendorf                    240454        89.46
# 8                      Spandau                    223962        91.91
# 9          Steglitz-Zehlendorf                    293989       102.50
# 10        Tempelhof-Schöneberg                    335060        53.09
# 11            Treptow-Köpenick                    241335       168.42
#
#     Density per km²  Map
# 0              4878  NaN
# 1             13187  NaN
# 2              4952  NaN
# 3              4046  NaN
# 4              8272  NaN
# 5              6804  NaN
# 6              3476  NaN
# 7              2712  NaN
# 8              2441  NaN
# 9              2818  NaN
# 10             6256  NaN
# 11             1406  NaN

# %%
berlin_district=get_lon_lat(berlin_data[0]['Borough'], 'Berlin', column_names)
berlin_district
# Out:
#       City                    District   Latitude  Longitude
# 0   Berlin  Charlottenburg-Wilmersdorf  52.507856  13.263952
# 1   Berlin    Friedrichshain-Kreuzberg  52.515306  13.461612
# 2   Berlin                 Lichtenberg  48.921296   7.481227
# 3   Berlin         Marzahn-Hellersdorf  52.522523  13.587663
# 4   Berlin                       Mitte  52.517690  13.402376
# 5   Berlin                    Neukölln  52.481150  13.435350
# 6   Berlin                      Pankow  52.597637  13.436374
# 7   Berlin               Reinickendorf  52.604763  13.295287
# 8   Berlin                     Spandau  52.535788  13.197792
# 9   Berlin         Steglitz-Zehlendorf  52.429205  13.229974
# 10  Berlin        Tempelhof-Schöneberg  52.440603  13.373703
# 11  Berlin            Treptow-Köpenick  52.417893  13.600185

# %% [markdown]
# <h2>New York Data</h2>

# %%
new_york_data=pd.read_html('https://en.wikipedia.org/wiki/Boroughs_of_New_York_City')
ny_data=new_york_data[0][0:5]
ny_data.columns=['Borough', 'Val1', 'Val1', 'Val1', 'Val1', 'Val1', 'Val1', 'Val1', 'Val1']
# Out:
#          Borough      Val1     Val1     Val1    Val1    Val1    Val1   Val1  \
# 0      The Bronx     Bronx  1418207   42.695   30100   42.10  109.04  33867
# 1       Brooklyn     Kings  2559903   91.559   35800   70.82  183.42  36147
# 2      Manhattan  New York  1628706  600.244  368500   22.83   59.13  71341
# 3         Queens    Queens  2253858   93.310   41400  108.53  281.09  20767
# 4  Staten Island  Richmond   476143   14.514   30500   58.37  151.18   8157
#
#     Val1
# 0  13006
# 1  13957
# 2  27544
# 3   8018
# 4   3150

# %%
ny_district=get_lon_lat(ny_data['Borough'], 'NY', column_names)
ny_district
# Out:
#   City       District   Latitude  Longitude
# 0   NY      The Bronx  40.846651 -73.878594
# 1   NY       Brooklyn  40.650104 -73.949582
# 2   NY      Manhattan  40.789624 -73.959894
# 3   NY         Queens  40.749824 -73.797634
# 4   NY  Staten Island  40.583456 -74.149605

# %% [markdown]
# <h2>Gather Data Into One DataFrame (final_df)</h2>

# %%
frames=[paris_district, tokyo_district, london_district, berlin_district, ny_district]
final_df=pd.concat(frames)
final_df.reset_index(drop=True, inplace=True)
final_df
# Out:
#       City                    District   Latitude   Longitude
# 0    Paris                   Vaugirard  48.840085    2.292826
# 1    Paris                       Opéra  48.877164    2.337458
# 2    Paris           Buttes-Montmartre  48.892569    2.348161
# 3    Paris                  Luxembourg  48.849130    2.332898
# 4    Paris                     Reuilly  48.834974    2.421325
# 5    Paris         Batignolles-Monceau  48.887327    2.306777
# 6    Paris                Ménilmontant  48.863461    2.401188
# 7    Paris                      Louvre  48.862563    2.336443
# 8    Paris                      Bourse  48.868279    2.342803
# 9    Paris             Buttes-Chaumont  48.887076    2.384821
# 10   Paris                    Panthéon  48.844443    2.350715
# 11   Paris                      Élysée  48.872721    2.312554
# 12   Paris                       Passy  48.860392    2.261971
# 13   Paris                    Entrepôt  48.876130    2.360728
# 14   Paris              Hôtel-de-Ville  48.854341    2.357630
# 15   Paris                Observatoire  48.829245    2.326542
# 16   Paris                  Popincourt  48.859059    2.380058
# 17   Paris                    Gobelins  48.828388    2.362272
# 18   Paris                      Temple  48.862872    2.360001
# 19   Paris              Palais-Bourbon  48.856174    2.312188
# 20   Tokyo                     Chiyoda  35.693810  139.753216
# 21   Tokyo                        Chūō  35.666255  139.775565
# 22   Tokyo                      Minato  35.643227  139.740055
# 23   Tokyo                    Shinjuku  35.693763  139.703632
# 24   Tokyo                      Bunkyō  35.718810  139.744732
# 25   Tokyo                       Taitō  35.717450  139.790859
# 26   Tokyo                      Sumida  35.700429  139.805017
# 27   Tokyo                        Kōtō  35.649154  139.812790
# 28   Tokyo                   Shinagawa  35.599252  139.738910
# 29   Tokyo                      Meguro  35.621250  139.688014
# ..     ...                         ...        ...         ...
# 63  London        Kingston upon Thames  51.409627   -0.306262
# 64  London                     Lambeth  51.501301   -0.117287
# 65  London                    Lewisham  51.462432   -0.010133
# 66  London                      Merton  51.410803   -0.188099
# 67  London                      Newham  51.530000    0.029318
# 68  London                   Redbridge  51.576320    0.045410
# 69  London        Richmond upon Thames  51.440372   -0.305720
# 70  London                   Southwark  51.502922   -0.103458
# 71  London                      Sutton  30.567295 -100.643236
# 72  London               Tower Hamlets  51.128863    1.298669
# 73  London              Waltham Forest  42.375640  -71.235800
# 74  London                  Wandsworth  51.457027   -0.193261
# 75  London                 Westminster  51.500444   -0.126540
# 76  Berlin  Charlottenburg-Wilmersdorf  52.507856   13.263952
# 77  Berlin    Friedrichshain-Kreuzberg  52.515306   13.461612
# 78  Berlin                 Lichtenberg  48.921296    7.481227
# 79  Berlin         Marzahn-Hellersdorf  52.522523   13.587663
# 80  Berlin                       Mitte  52.517690   13.402376
# 81  Berlin                    Neukölln  52.481150   13.435350
# 82  Berlin                      Pankow  52.597637   13.436374
# 83  Berlin               Reinickendorf  52.604763   13.295287
# 84  Berlin                     Spandau  52.535788   13.197792
# 85  Berlin         Steglitz-Zehlendorf  52.429205   13.229974
# 86  Berlin        Tempelhof-Schöneberg  52.440603   13.373703
# 87  Berlin            Treptow-Köpenick  52.417893   13.600185
# 88      NY                   The Bronx  40.846651  -73.878594
# 89      NY                    Brooklyn  40.650104  -73.949582
# 90      NY                   Manhattan  40.789624  -73.959894
# 91      NY                      Queens  40.749824  -73.797634
# 92      NY               Staten Island  40.583456  -74.149605
#
# [93 rows x 4 columns]

# %% [markdown]
# <h2>Get Data From Foursquare to get nearby venues</h2>

# %%
#Foursquare API:
CLIENT_ID = '' 
CLIENT_SECRET = ''
VERSION = '20180605' 
LIMIT = 100

# %%
def getNearbyPlaces(district_data, radius=1000):
    places_list=[]
    for index, singleRow in district_data.iterrows():
        try:
            url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
                CLIENT_ID, 
                CLIENT_SECRET, 
                VERSION, 
                float(singleRow['Latitude']), 
                float(singleRow['Longitude']), 
                radius, 
                LIMIT)
            results = requests.get(url).json()["response"]['groups'][0]['items']
            places_list.append([(
                singleRow['City'],
                singleRow['District'], 
                singleRow['Latitude'], 
                singleRow['Longitude'],
                p['venue']['name'], 
                p['venue']['location']['lat'], 
                p['venue']['location']['lng'],  
                p['venue']['categories'][0]['name']) for p in results])
        except:
            pass
    nearby_places = pd.DataFrame([item for place_list in places_list for item in place_list])
    nearby_places.columns = ['City', 
                            'District',
                  'District Latitude', 
                  'District Longitude', 
                  'Place', 
                  'Place Latitude', 
                  'Place Longitude', 
                  'Place Category']
    
    return(nearby_places)

# %%
near_places=getNearbyPlaces(final_df)

# %%
near_places
# Out:
#        City       District  District Latitude  District Longitude  \
# 0     Paris      Vaugirard          48.840085            2.292826
# 1     Paris      Vaugirard          48.840085            2.292826
# 2     Paris      Vaugirard          48.840085            2.292826
# 3     Paris      Vaugirard          48.840085            2.292826
# 4     Paris      Vaugirard          48.840085            2.292826
# 5     Paris      Vaugirard          48.840085            2.292826
# 6     Paris      Vaugirard          48.840085            2.292826
# 7     Paris      Vaugirard          48.840085            2.292826
# 8     Paris      Vaugirard          48.840085            2.292826
# 9     Paris      Vaugirard          48.840085            2.292826
# 10    Paris      Vaugirard          48.840085            2.292826
# 11    Paris      Vaugirard          48.840085            2.292826
# 12    Paris      Vaugirard          48.840085            2.292826
# 13    Paris      Vaugirard          48.840085            2.292826
# 14    Paris      Vaugirard          48.840085            2.292826
# 15    Paris      Vaugirard          48.840085            2.292826
# 16    Paris      Vaugirard          48.840085            2.292826
# 17    Paris      Vaugirard          48.840085            2.292826
# 18    Paris      Vaugirard          48.840085            2.292826
# 19    Paris      Vaugirard          48.840085            2.292826
# 20    Paris      Vaugirard          48.840085            2.292826
# 21    Paris      Vaugirard          48.840085            2.292826
# 22    Paris      Vaugirard          48.840085            2.292826
# 23    Paris      Vaugirard          48.840085            2.292826
# 24    Paris      Vaugirard          48.840085            2.292826
# 25    Paris      Vaugirard          48.840085            2.292826
# 26    Paris      Vaugirard          48.840085            2.292826
# 27    Paris      Vaugirard          48.840085            2.292826
# 28    Paris      Vaugirard          48.840085            2.292826
# 29    Paris      Vaugirard          48.840085            2.292826
# ...     ...            ...                ...                 ...
# 6470     NY         Queens          40.749824          -73.797634
# 6471     NY         Queens          40.749824          -73.797634
# 6482                MooKyoDong YooJung Nakji (무교동 유정낙지)       40.758223
# 6483                                      Basak chicken       40.758197
# 6484                                     Queen Bee Deli       40.756464
# 6485                                 Muhsins Halal Food       40.757811
# 6486                               Underhill Playground       40.744908
# 6487                                    Plautt Triangle       40.758632
# 6488                            Greenbelt Nature Center       40.586616
# 6489                            La Tourette Golf Course       40.575603
# 6490                            La Tourette Golf Course       40.576122
# 6491                                             SUBWAY       40.587029
# 6492                                       CVS pharmacy       40.581150
# 6493                                    Greenbelt Trail       40.586655
# 6494                                    LaTourette Park       40.581923
# 6495  MTA Bus - Forest Hill Rd & Rockland Av (S61/S9...       40.588822
# 6496                                          Marsh Ave       40.581331
# 6497                                   Doctor Computers       40.591361
# 6498  MTA Bus - Marsh Av & Ring Rd (S44/S55/S56/S59/...       40.584248
# 6499       MTA Bus - Travis Av & Evans St (S61/S91/X31)       40.591590
#
#       Place Longitude           Place Category
# 0            2.291621        Indian Restaurant
# 1            2.294484       Italian Restaurant
# 2            2.288607      Lebanese Restaurant
# 3            2.297108                     Park
# 4            2.297156      Lebanese Restaurant
# 5            2.293377           Ice Cream Shop
# 6            2.291783        Basque Restaurant
# 7            2.289383                     Park
# 8            2.292199                      Gym
# 9            2.292473                Hotel Bar
# 10           2.293037               Sports Bar
# 11           2.295248       Russian Restaurant
# 12           2.291299        French Restaurant
# 13           2.292587                   Hostel
# 14           2.298837                Bookstore
# 15           2.293894                    Plaza
# 16           2.299388        Korean Restaurant
# 17           2.297379        French Restaurant
# 18           2.294499       Italian Restaurant
# 19           2.293993       Persian Restaurant
# 20           2.300375        French Restaurant
# 21           2.290500                    Hotel
# 22           2.294476       Italian Restaurant
# 23           2.288961               Restaurant
# 24           2.295293          Thai Restaurant
# 25           2.293419                Brasserie
# 26           2.296601       Italian Restaurant
# 27           2.286971        French Restaurant
# 28           2.291941          Thai Restaurant
# 29           2.288777  Scandinavian Restaurant
# ...               ...                      ...
# 6470       -73.795449        Korean Restaurant
# 6471       -73.797699              Sports Club
# 6472       -73.799391               Bike Trail
# 6473       -73.801613              Bus Station
# 6474       -73.792766             Liquor Store
# 6475       -73.791832            Grocery Store
# 6476       -73.803075                     Park
# 6477       -73.805861                     Lake
# 6478       -73.805237                      Spa
# 6479       -73.805038                Pet Store
# 6480       -73.788094     Arts & Entertainment
# 6481       -73.804426              Pizza Place
# 6482       -73.795791        Korean Restaurant
# 6483       -73.795486      Fried Chicken Joint
# 6484       -73.804755            Deli / Bodega
# 6485       -73.793441               Food Truck
# 6486       -73.787846               Playground
# 6487       -73.799490                     Park
# 6488       -74.146917                    Trail
# 6489       -74.147487              Golf Course
# 6490       -74.146822              Golf Course
# 6491       -74.152155           Sandwich Place
# 6492       -74.156524                 Pharmacy
# 6493       -74.147020                    Trail
# 6494       -74.142737                     Park
# 6495       -74.146873                 Bus Stop
# 6496       -74.157746            Moving Target
# 6497       -74.153617              IT Services
# 6498       -74.160776                 Bus Stop
# 6499       -74.153850                 Bus Stop
#
# [6500 rows x 8 columns]
